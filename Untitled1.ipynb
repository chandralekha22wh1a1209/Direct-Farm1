# %% [markdown]
# <a href="https://colab.research.google.com/github/chandralekha22wh1a1209/Direct-Farm1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set a style for better aesthetics
sns.set_style("whitegrid")

# %%
commodity_data = [
  {
    "name": "Tomato",
    "farm_price": 20,
    "retail_price": 38.9,
    "unit": "kg",
    "image": "/images/Tomato.jpg",
    "category": "Vegetables",
    "farmer": "Raju",
    "locality": "Nalgonda"
  },
  {
    "name": "Potato",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Potato.jpg",
    "category": "Vegetables",
    "farmer": "Sita",
    "locality": "Warangal"
  },
  {
    "name": "Onion",
    "farm_price": 20,
    "retail_price": 22,
    "unit": "kg",
    "image": "/images/Onion.jpg",
    "category": "Vegetables",
    "farmer": "Lakshman",
    "locality": "Kurnool"
  },
  {
    "name": "Carrot",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/Carrot.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Vijayawada"
  },
  {
    "name": "Cauliflower",
    "farm_price": 25,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Cauliflower.webp",
    "category": "Vegetables",
    "farmer": "Ramesh",
    "locality": "Tirupati"
  },
  {
    "name": "Brinjal",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Brinjal.jpg",
    "category": "Vegetables",
    "farmer": "Anita",
    "locality": "Kadapa"
  },
  {
    "name": "Spinach",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "bundle",
    "image": "/images/Spinach.webp",
    "category": "Vegetables",
    "farmer": "Prakash",
    "locality": "Guntur"
  },
  {
    "name": "Cabbage",
    "farm_price": 20,
    "retail_price": 25,
    "unit": "kg",
    "image": "/images/Cabbage.jpg",
    "category": "Vegetables",
    "farmer": "Sundar",
    "locality": "Rajahmundry"
  },
  {
    "name": "Peas",
    "farm_price": 105,
    "retail_price": 120,
    "unit": "kg",
    "image": "/images/Peas.webp",
    "category": "Vegetables",
    "farmer": "Radha",
    "locality": "Vizag"
  },
  {
    "name": "Radish",
    "farm_price": 40,
    "retail_price": 50,
    "unit": "kg",
    "image": "/images/Raddish.webp",
    "category": "Vegetables",
    "farmer": "Vikram",
    "locality": "Anantapur"
  },
  {
    "name": "Pumpkin",
    "farm_price": 120,
    "retail_price": 150,
    "unit": "kg",
    "image": "/images/Pumpkin.jpg",
    "category": "Vegetables",
    "farmer": "Lakshmi",
    "locality": "Khammam"
  },
  {
    "name": "Bottle Gourd",
    "farm_price": 26,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Bottlegourd.webp",
    "category": "Vegetables",
    "farmer": "Suresh",
    "locality": "Nellore"
  },
  {
    "name": "Bitter Gourd",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Bittergourd.jpg",
    "category": "Vegetables",
    "farmer": "Geetha",
    "locality": "Kakinada"
  },
  {
    "name": "Okra",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Okra.avif",
    "category": "Vegetables",
    "farmer": "Manoj",
    "locality": "Eluru"
  },
  {
    "name": "Sweet Corn",
    "farm_price": 47,
    "retail_price": 60,
    "unit": "kg",
    "image": "/images/Sweetcorn.webp",
    "category": "Vegetables",
    "farmer": "Bhavani",
    "locality": "Chittoor"
  },
  {
    "name": "Green Beans",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/GreenBeans.jpg",
    "category": "Vegetables",
    "farmer": "Sanjay",
    "locality": "Adilabad"
  },
  {
    "name": "Garlic",
    "farm_price": 200,
    "retail_price": 250,
    "unit": "kg",
    "image": "/images/Garlic.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Medak"
  },
  {
    "name": "Ginger",
    "farm_price": 9
# Out:
#   File "<ipython-input-2-8398cb75f8af>", line 2
#     {
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
commodity_data = [
    {
        "name": "Tomato",
        "farm_price": 20,
        "retail_price": 38.9,
        "unit": "kg",
        "image": "/images/Tomato.jpg",
        "category": "Vegetables",
        "farmer": "Raju",
        "locality": "Nalgonda"
    },
     {
    "name": "Potato",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Potato.jpg",
    "category": "Vegetables",
    "farmer": "Sita",
    "locality": "Warangal"
  },
  {
    "name": "Onion",
    "farm_price": 20,
    "retail_price": 22,
    "unit": "kg",
    "image": "/images/Onion.jpg",
    "category": "Vegetables",
    "farmer": "Lakshman",
    "locality": "Kurnool"
  },
  {
    "name": "Carrot",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/Carrot.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Vijayawada"
  },
  {
    "name": "Cauliflower",
    "farm_price": 25,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Cauliflower.webp",
    "category": "Vegetables",
    "farmer": "Ramesh",
    "locality": "Tirupati"
  },
  {
    "name": "Brinjal",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Brinjal.jpg",
    "category": "Vegetables",
    "farmer": "Anita",
    "locality": "Kadapa"
  },
  {
    "name": "Spinach",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "bundle",
    "image": "/images/Spinach.webp",
    "category": "Vegetables",
    "farmer": "Prakash",
    "locality": "Guntur"
  },
  {
    "name": "Cabbage",
    "farm_price": 20,
    "retail_price": 25,
    "unit": "kg",
    "image": "/images/Cabbage.jpg",
    "category": "Vegetables",
    "farmer": "Sundar",
    "locality": "Rajahmundry"
  },
  {
    "name": "Peas",
    "farm_price": 105,
    "retail_price": 120,
    "unit": "kg",
    "image": "/images/Peas.webp",
    "category": "Vegetables",
    "farmer": "Radha",
    "locality": "Vizag"
  },
  {
    "name": "Radish",
    "farm_price": 40,
    "retail_price": 50,
    "unit": "kg",
    "image": "/images/Raddish.webp",
    "category": "Vegetables",
    "farmer": "Vikram",
    "locality": "Anantapur"
  },
  {
    "name": "Pumpkin",
    "farm_price": 120,
    "retail_price": 150,
    "unit": "kg",
    "image": "/images/Pumpkin.jpg",
    "category": "Vegetables",
    "farmer": "Lakshmi",
    "locality": "Khammam"
  },
  {
    "name": "Bottle Gourd",
    "farm_price": 26,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Bottlegourd.webp",
    "category": "Vegetables",
    "farmer": "Suresh",
    "locality": "Nellore"
  },
  {
    "name": "Bitter Gourd",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Bittergourd.jpg",
    "category": "Vegetables",
    "farmer": "Geetha",
    "locality": "Kakinada"
  },
  {
    "name": "Okra",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Okra.avif",
    "category": "Vegetables",
    "farmer": "Manoj",
    "locality": "Eluru"
  },
  {
    "name": "Sweet Corn",
    "farm_price": 47,
    "retail_price": 60,
    "unit": "kg",
    "image": "/images/Sweetcorn.webp",
    "category": "Vegetables",
    "farmer": "Bhavani",
    "locality": "Chittoor"
  },
  {
    "name": "Green Beans",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/GreenBeans.jpg",
    "category": "Vegetables",
    "farmer": "Sanjay",
    "locality": "Adilabad"
  },
  {
    "name": "Garlic",
    "farm_price": 200,
    "retail_price": 250,
    "unit": "kg",
    "image": "/images/Garlic.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Medak"
  },
  {
    "name": "Ginger",
    "farm_price": 91,
    "retail_price": 120,
    "unit": "kg",
    "image": "/images/Ginger.jpg",
    "category": "Vegetables",
    "farmer": "Ravi",
    "locality": "Nizamabad"
  },
  {
    "name": "Chili",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Chili.jpg",
    "category": "Vegetables",
    "farmer": "Kiran",
    "locality": "Mahbubnagar"
  },
  {
    "name": "Cucumber",
    "farm_price": 28,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Cucumber.jpg",
    "category": "Vegetables",
    "farmer": "Swapna",
    "locality": "Srikakulam"
  },
  {
    "name": "Apple",
    "farm_price": 13,
    "retail_price": 40,
    "unit": "pcs",
    "image": "/images/Apple.webp",
    "category": "Fruits",
    "farmer": "John",
    "locality": "Shimla"
  },
  {
    "name": "Banana",
    "farm_price": 40,
    "retail_price": 80,
    "unit": "dozen",
    "image": "/images/Bannana.jpg",
    "category": "Fruits",
    "farmer": "Priya",
    "locality": "TamilNadu"
  },
  {
    "name": "Mango",
    "farm_price": 22.75,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/Mango.webp",
    "category": "Fruits",
    "farmer": "Anil",
    "locality": "UttarPradesh"
  },
  {
    "name": "Pineapple",
    "farm_price": 40,
    "retail_price": 60,
    "unit": "pcs",
    "image": "/images/Pineapple.webp",
    "category": "Fruits",
    "farmer": "Mary",
    "locality": "Vazhakulam"
  },
  {
    "name": "Papaya",
    "farm_price": 31,
    "retail_price": 50,
    "unit": "pcs",
    "image": "/images/Papaya.jpg",
    "category": "Fruits",
    "farmer": "Kumar",
    "locality": "Rajahmundry"
  },
  {
    "name": "Grapes",
    "farm_price": 100,
    "retail_price": 150,
    "unit": "kg",
    "image": "/images/Grapes.webp",
    "category": "Fruits",
    "farmer": "Sonal",
    "locality": "Nasik"
  },
  {
    "name": "Watermelon",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "pcs",
    "image": "/images/Watermelon.webp",
    "category": "Fruits",
    "farmer": "Deepak",
    "locality": "Karnataka"
  },
  {
    "name": "Orange",
    "farm_price": 4.80,
    "retail_price": 10,
    "unit": "pcs",
    "image": "/images/Orange.webp",
    "category": "Fruits",
    "farmer": "Sneha",
    "locality": "Nagpur"
  },
  {
    "name": "Lemon",
    "farm_price": 7.20,
    "retail_price": 15,
    "unit": "pcs",
    "image": "/images/Lemon.jpg",
    "category": "Fruits",
    "farmer": "Rajesh",
    "locality": "Ukhrul"
  },
  {
    "name": "Guava",
    "farm_price": 5.50,
    "retail_price": 15,
    "unit": "pcs",
    "image": "/images/Guava.webp",
    "category": "Fruits",
    "farmer": "Rekha",
    "locality": "Bihar"
  },
];

# %%
import pandas as pd
import altair as alt

# Commodity data
commodity_data = [
    {
        "name": "Tomato",
        "farm_price": 20,
        "retail_price": 38.9,
        "unit": "kg",
        "image": "/images/Tomato.jpg",
        "category": "Vegetables",
        "farmer": "Raju",
        "locality": "Nalgonda"
    },
      {
    "name": "Potato",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Potato.jpg",
    "category": "Vegetables",
    "farmer": "Sita",
    "locality": "Warangal"
  },
  {
    "name": "Onion",
    "farm_price": 20,
    "retail_price": 22,
    "unit": "kg",
    "image": "/images/Onion.jpg",
    "category": "Vegetables",
    "farmer": "Lakshman",
    "locality": "Kurnool"
  },
  {
    "name": "Carrot",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/Carrot.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Vijayawada"
  },
  {
    "name": "Cauliflower",
    "farm_price": 25,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Cauliflower.webp",
    "category": "Vegetables",
    "farmer": "Ramesh",
    "locality": "Tirupati"
  },
  {
    "name": "Brinjal",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Brinjal.jpg",
    "category": "Vegetables",
    "farmer": "Anita",
    "locality": "Kadapa"
  },
  {
    "name": "Spinach",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "bundle",
    "image": "/images/Spinach.webp",
    "category": "Vegetables",
    "farmer": "Prakash",
    "locality": "Guntur"
  },
  {
    "name": "Cabbage",
    "farm_price": 20,
    "retail_price": 25,
    "unit": "kg",
    "image": "/images/Cabbage.jpg",
    "category": "Vegetables",
    "farmer": "Sundar",
    "locality": "Rajahmundry"
  },
  {
    "name": "Peas",
    "farm_price": 105,
    "retail_price": 120,
    "unit": "kg",
    "image": "/images/Peas.webp",
    "category": "Vegetables",
    "farmer": "Radha",
    "locality": "Vizag"
  },
  {
    "name": "Radish",
    "farm_price": 40,
    "retail_price": 50,
    "unit": "kg",
    "image": "/images/Raddish.webp",
    "category": "Vegetables",
    "farmer": "Vikram",
    "locality": "Anantapur"
  },
  {
    "name": "Pumpkin",
    "farm_price": 120,
    "retail_price": 150,
    "unit": "kg",
    "image": "/images/Pumpkin.jpg",
    "category": "Vegetables",
    "farmer": "Lakshmi",
    "locality": "Khammam"
  },
  {
    "name": "Bottle Gourd",
    "farm_price": 26,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Bottlegourd.webp",
    "category": "Vegetables",
    "farmer": "Suresh",
    "locality": "Nellore"
  },
  {
    "name": "Bitter Gourd",
    "farm_price": 30,
    "retail_price": 40,
    "unit": "kg",
    "image": "/images/Bittergourd.jpg",
    "category": "Vegetables",
    "farmer": "Geetha",
    "locality": "Kakinada"
  },
  {
    "name": "Okra",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Okra.avif",
    "category": "Vegetables",
    "farmer": "Manoj",
    "locality": "Eluru"
  },
  {
    "name": "Sweet Corn",
    "farm_price": 47,
    "retail_price": 60,
    "unit": "kg",
    "image": "/images/Sweetcorn.webp",
    "category": "Vegetables",
    "farmer": "Bhavani",
    "locality": "Chittoor"
  },
  {
    "name": "Green Beans",
    "farm_price": 35,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/GreenBeans.jpg",
    "category": "Vegetables",
    "farmer": "Sanjay",
    "locality": "Adilabad"
  },
  {
    "name": "Garlic",
    "farm_price": 200,
    "retail_price": 250,
    "unit": "kg",
    "image": "/images/Garlic.jpg",
    "category": "Vegetables",
    "farmer": "Meena",
    "locality": "Medak"
  },
  {
    "name": "Ginger",
    "farm_price": 91,
    "retail_price": 120,
    "unit": "kg",
    "image": "/images/Ginger.jpg",
    "category": "Vegetables",
    "farmer": "Ravi",
    "locality": "Nizamabad"
  },
  {
    "name": "Chili",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "kg",
    "image": "/images/Chili.jpg",
    "category": "Vegetables",
    "farmer": "Kiran",
    "locality": "Mahbubnagar"
  },
  {
    "name": "Cucumber",
    "farm_price": 28,
    "retail_price": 35,
    "unit": "kg",
    "image": "/images/Cucumber.jpg",
    "category": "Vegetables",
    "farmer": "Swapna",
    "locality": "Srikakulam"
  },
  {
    "name": "Apple",
    "farm_price": 13,
    "retail_price": 40,
    "unit": "pcs",
    "image": "/images/Apple.webp",
    "category": "Fruits",
    "farmer": "John",
    "locality": "Shimla"
  },
  {
    "name": "Banana",
    "farm_price": 40,
    "retail_price": 80,
    "unit": "dozen",
    "image": "/images/Bannana.jpg",
    "category": "Fruits",
    "farmer": "Priya",
    "locality": "TamilNadu"
  },
  {
    "name": "Mango",
    "farm_price": 22.75,
    "retail_price": 45,
    "unit": "kg",
    "image": "/images/Mango.webp",
    "category": "Fruits",
    "farmer": "Anil",
    "locality": "UttarPradesh"
  },
  {
    "name": "Pineapple",
    "farm_price": 40,
    "retail_price": 60,
    "unit": "pcs",
    "image": "/images/Pineapple.webp",
    "category": "Fruits",
    "farmer": "Mary",
    "locality": "Vazhakulam"
  },
  {
    "name": "Papaya",
    "farm_price": 31,
    "retail_price": 50,
    "unit": "pcs",
    "image": "/images/Papaya.jpg",
    "category": "Fruits",
    "farmer": "Kumar",
    "locality": "Rajahmundry"
  },
  {
    "name": "Grapes",
    "farm_price": 100,
    "retail_price": 150,
    "unit": "kg",
    "image": "/images/Grapes.webp",
    "category": "Fruits",
    "farmer": "Sonal",
    "locality": "Nasik"
  },
  {
    "name": "Watermelon",
    "farm_price": 20,
    "retail_price": 30,
    "unit": "pcs",
    "image": "/images/Watermelon.webp",
    "category": "Fruits",
    "farmer": "Deepak",
    "locality": "Karnataka"
  },
  {
    "name": "Orange",
    "farm_price": 4.80,
    "retail_price": 10,
    "unit": "pcs",
    "image": "/images/Orange.webp",
    "category": "Fruits",
    "farmer": "Sneha",
    "locality": "Nagpur"
  },
  {
    "name": "Lemon",
    "farm_price": 7.20,
    "retail_price": 15,
    "unit": "pcs",
    "image": "/images/Lemon.jpg",
    "category": "Fruits",
    "farmer": "Rajesh",
    "locality": "Ukhrul"
  },
  {
    "name": "Guava",
    "farm_price": 5.50,
    "retail_price": 15,
    "unit": "pcs",
    "image": "/images/Guava.webp",
    "category": "Fruits",
    "farmer": "Rekha",
    "locality": "Bihar"
  },
]

# Create a DataFrame from the commodity data
df = pd.DataFrame(commodity_data)

# Calculate the price difference
df['price_difference'] = df['retail_price'] - df['farm_price']

# Create a bar chart
chart = alt.Chart(df).mark_bar().encode(
    x=alt.X('name:N', title='Commodity'),
    y=alt.Y('price_difference:Q', title='Price Difference (Retail - Farm)'),
    tooltip=['name', 'farm_price', 'retail_price', 'price_difference']
).properties(
    title='Difference Between Direct Farm and Retail Prices'
).interactive() # Make the chart interactive for zooming and panning

# Display the chart (this will render directly in Colab)
chart
# Out:
# alt.Chart(...)
